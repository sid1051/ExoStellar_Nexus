# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/toshika/.local/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/toshika/.local/lib/python3.10/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
print(cv2.__version__)
# Out:
# 4.10.0

# %%
from IPython.display import Image

# %%
img=Image(url="Scorpius.png", width=15, height=15)

# %% [markdown]
# ![Scorpius.png](attachment:6d462cd6-39d5-49fb-b9dc-ab93a424d49f.png)

# %%
img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       2 sharpened = float(amount + 1) * image - float(amount) * blurred
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
def unsharp_mask(image, kernel_size=(5, 5), sigma=1.0, amount=1.0, threshold=0):
    """Return a sharpened version of the image, using an unsharp mask."""
    blurred = cv2.GaussianBlur(image, kernel_size, sigma)
    sharpened = float(amount + 1) * image - float(amount) * blurred
    sharpened = np.maximum(sharpened, np.zeros(sharpened.shape))
    sharpened = np.minimum(sharpened, 255 * np.ones(sharpened.shape))
    sharpened = sharpened.round().astype(np.uint8)
    if threshold > 0:
        low_contrast_mask = np.absolute(image - blurred) < threshold
        np.copyto(sharpened, image, where=low_contrast_mask)
    return sharpened
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[52], line 12
#      10         np.copyto(sharpened, image, where=low_contrast_mask)
#      11     return sharpened
# ---> 12 sharpened_image = unsharp_mask(img)
#
# Cell In[52], line 3, in unsharp_mask(image, kernel_size, sigma, amount, threshold)
#       1 def unsharp_mask(image, kernel_size=(5, 5), sigma=1.0, amount=1.0, threshold=0):
#       2     """Return a sharpened version of the image, using an unsharp mask."""
# ----> 3     blurred = cv2.GaussianBlur(image, kernel_size, sigma)
#       4     sharpened = float(amount + 1) * image - float(amount) * blurred
#       5     sharpened = np.maximum(sharpened, np.zeros(sharpened.shape))
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'GaussianBlur'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
sharpened_image = unsharp_mask(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 sharpened_image = unsharp_mask(img)
#
# Cell In[52], line 3, in unsharp_mask(image, kernel_size, sigma, amount, threshold)
#       1 def unsharp_mask(image, kernel_size=(5, 5), sigma=1.0, amount=1.0, threshold=0):
#       2     """Return a sharpened version of the image, using an unsharp mask."""
# ----> 3     blurred = cv2.GaussianBlur(image, kernel_size, sigma)
#       4     sharpened = float(amount + 1) * image - float(amount) * blurred
#       5     sharpened = np.maximum(sharpened, np.zeros(sharpened.shape))
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'GaussianBlur'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
