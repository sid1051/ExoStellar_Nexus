# %%
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib

# %%
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_main=pd.read_csv('https://raw.githubusercontent.com/D3bug1t/ExoStellar_Nexus/6eead614ef932da8a2421f13bb22ccad44f45d78/Assignments/Assignment-2/advertising.csv')

# %%
dataset_main
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
y=dataset_main['Sales']
x1=dataset_main['TV']
x2=dataset_main['Radio']
x3=dataset_main['Newspaper']

# %%
plt.scatter(x1,y)
plt.xlabel('TV') 
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
from sklearn.model_selection import train_test_split
x1_train, x1_test, y1_train, y1_test = train_test_split(x1,y, test_size=0.4, random_state=32)
x1_train=np.array(x1_train).reshape(-1,1)
x1_test=np.array(x1_test).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr1=LinearRegression()
lr1.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
c1=lr1.intercept_
c1
# Out:
# 7.045650553711389

# %%
m1=lr1.coef_
m1
# Out:
# array([0.05507418])

# %%
y1_train_pred=lr1.predict(x1_train)
plt.plot(x1_train,y1_train_pred, color="red")
plt.scatter(x1_train,y1_train)

# %%
y1_test_pred=lr1.predict(x1_test)
plt.plot(x1_test,y1_test_pred, color="red")
plt.scatter(x1_test,y1_test)

# %%
y1_test=np.array(y1_test)
y1_avg=0
rss1=0
tss1=0
for i in range(80):
    y1_avg=y1_avg+y1_test[i]
    s1=(y1_test[i]-y1_test_pred[i])*(y1_test[i]-y1_test_pred[i])
    rss1=s1+rss1

for i in range(80):
    s_1=(y1_test[i]-y1_avg)*(y1_test[i]-y1_avg)
    tss1=tss1+s_1    
    
r2_1=1-(rss1/tss1)
r2_1
# Out:
# 0.9999962880760128

# %%
plt.scatter(x2,y)
plt.xlabel('Radio')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
x2_train, x2_test, y2_train, y2_test = train_test_split(x2,y, test_size=0.4, random_state=32)
x2_train=np.array(x2_train).reshape(-1,1)
x2_test=np.array(x2_test).reshape(-1,1)

# %%
lr2=LinearRegression()
lr2.fit(x2_train,y2_train)
# Out:
# LinearRegression()

# %%
c2=lr2.intercept_
c2
# Out:
# 11.543672527350736

# %%
m2=lr2.coef_
m2
# Out:
# array([0.1423534])

# %%
y2_train_pred=x2_train*m2+c2
plt.plot(x2_train,y2_train_pred, color="red")
plt.scatter(x2_train,y2_train)

# %%
y2_test_pred=x2_test*m2+c2
plt.plot(x2_test,y2_test_pred, color="red")
plt.scatter(x2_test,y2_test)

# %%
y2_test=np.array(y2_test)
y2_avg=0
rss2=0
tss2=0
for i in range(80):
    y2_avg=y2_avg+y2_test[i]
    s2=(y2_test[i]-y2_test_pred[i])*(y2_test[i]-y2_test_pred[i])
    rss2=s2+rss2

for i in range(80):
    s_2=(y2_test[i]-y2_avg)*(y2_test[i]-y2_avg)
    tss2=tss2+s_2    
    
r2_2=1-(rss2/tss2)
r2_2
# Out:
# array([0.99998245])

# %%
plt.scatter(x3,y)
plt.xlabel('Newspaper')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
x3_train, x3_test, y3_train, y3_test = train_test_split(x3,y, test_size=0.4, random_state=32)
x3_train=np.array(x3_train).reshape(-1,1)
x3_test=np.array(x3_test).reshape(-1,1)

# %%
lr3=LinearRegression()
lr3.fit(x3_train,y3_train)
# Out:
# LinearRegression()

# %%
c3=lr3.intercept_
c3
# Out:
# 12.747703356418072

# %%
m3=lr3.coef_
m3
# Out:
# array([0.07433949])

# %%
y3_train_pred=lr3.predict(x3_train)
plt.plot(x3_train,y3_train_pred, color="red")
plt.scatter(x3_train,y3_train)

# %%
y3_test_pred=x3_test*m3+c3
plt.plot(x3_test,y3_test_pred, color="red")
plt.scatter(x3_test,y3_test)

# %%
y3_test=np.array(y3_test)
y3_avg=0
rss3=0
tss3=0
for i in range(80):
    y3_avg=y3_avg+y3_test[i]
    s3=(y3_test[i]-y3_test_pred[i])*(y3_test[i]-y3_test_pred[i])
    rss3=s3+rss3

for i in range(80):
    s_3=(y3_test[i]-y3_avg)*(y3_test[i]-y3_avg)
    tss3=tss3+s_3    
    
r2_3=1-(rss3/tss3)
r2_3
# Out:
# array([0.99997969])
